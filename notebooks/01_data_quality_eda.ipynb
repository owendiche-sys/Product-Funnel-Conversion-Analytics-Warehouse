# %% [markdown]
# # Data Quality and EDA
#
# Use this notebook to inspect raw tables, missing values, row counts, funnel distributions, and validation results after running `python scripts/run_pipeline.py`.
